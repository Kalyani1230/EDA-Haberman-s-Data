# %% [markdown]
# # Exploratory Data Analysis on Haberman's Cancer Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('C:/Users/kalyani raghavendra/Desktop/appliedai data/haberman.csv')
data
# Out:
#      Age  Operating Year  Axil nodes  Survival Statistics  Unnamed: 4  \
# 0     30              64           1                    1         NaN
# 1     30              62           3                    1         NaN
# 2     30              65           0                    1         NaN
# 3     31              59           2                    1         NaN
# 4     31              65           4                    1         NaN
# ..   ...             ...         ...                  ...         ...
# 301   75              62           1                    1         NaN
# 302   76              67           0                    1         NaN
# 303   77              65           3                    1         NaN
# 304   78              65           1                    2         NaN
# 305   83              58           2                    2         NaN
#
#      Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10
# ...

# %%
data.drop(["Unnamed: 4","Unnamed: 5","Unnamed: 6","Unnamed: 7","Unnamed: 8","Unnamed: 9","Unnamed: 10"], 
          axis = 1, inplace = True)

# %%
data
# Out:
#      Age  Operating Year  Axil nodes  Survival Statistics
# 0     30              64           1                    1
# 1     30              62           3                    1
# 2     30              65           0                    1
# 3     31              59           2                    1
# 4     31              65           4                    1
# ..   ...             ...         ...                  ...
# 301   75              62           1                    1
# 302   76              67           0                    1
# 303   77              65           3                    1
# 304   78              65           1                    2
# 305   83              58           2                    2
#
# [306 rows x 4 columns]

# %%
data.head()
# Out:
#    Age  Operating Year  Axil nodes  Survival Statistics
# 0   30              64           1                    1
# 1   30              62           3                    1
# 2   30              65           0                    1
# 3   31              59           2                    1
# 4   31              65           4                    1

# %%
data.tail()
# Out:
#      Age  Operating Year  Axil nodes  Survival Statistics
# 301   75              62           1                    1
# 302   76              67           0                    1
# 303   77              65           3                    1
# 304   78              65           1                    2
# 305   83              58           2                    2

# %%
data.describe()
# Out:
#               Age  Operating Year  Axil nodes  Survival Statistics
# count  306.000000      306.000000  306.000000           306.000000
# mean    52.457516       62.852941    4.026144             1.264706
# std     10.803452        3.249405    7.189654             0.441899
# min     30.000000       58.000000    0.000000             1.000000
# 25%     44.000000       60.000000    0.000000             1.000000
# 50%     52.000000       63.000000    1.000000             1.000000
# 75%     60.750000       65.750000    4.000000             2.000000
# max     83.000000       69.000000   52.000000             2.000000

# %% [markdown]
# The data has 306 rows and 4 columns. The minimum age of the patient is 30 years. The maximum age of the patient is 83 years. A maximum of 52 nodes were present in a patient and about 75% of the patients had less than 4 axil nodes also 25% of them had no nodes. The data collected ranges from the year 1958 to 1969.

# %%
len(data)
# Out:
# 306

# %%
data.shape
# Out:
# (306, 4)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 4 columns):
# Age                    306 non-null int64
# Operating Year         306 non-null int64
# Axil nodes             306 non-null int64
# Survival Statistics    306 non-null int64
# dtypes: int64(4)
# memory usage: 9.7 KB

# %%
data["Age"].nunique()
# Out:
# 49

# %%
data["Operating Year"].nunique()
# Out:
# 12

# %%
data["Survival Statistics"].value_counts()
# Out:
# 1    225
# 2     81
# Name: Survival Statistics, dtype: int64

# %% [markdown]
# The number of people who survived the operation and lived for more than 5 years post it are 225 and 81 of them lost their lives before completeing 5 years after operation.

# %% [markdown]
# The objective of this case study is to find whether the patient who has undergone the treatment will survive more than 5 years or not based on their age, operating year and the number of auxiliary nodes detected in their body.

# %%
plt.hist(data["Age"], color = 'blue', edgecolor = 'black',bins = 5)
plt.xlabel("Age of the patient")
plt.show()

# %%
plt.hist(data["Operating Year"], color = 'blue', edgecolor = 'black', bins = 5)
plt.xlabel("Year the operation was performed")
plt.show()

# %%
plt.hist(data["Axil nodes"], color = 'blue', edgecolor = 'black', bins = 8)
plt.xlabel("Number of positive nodes")
plt.show()

# %%
sns.FacetGrid(data, hue = "Survival Statistics", size =5)\
   .map(sns.distplot, "Age")\
   .add_legend();
plt.show();
# Out:
# C:\Users\kalyani raghavendra\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(data, hue = "Survival Statistics", size =5)\
   .map(sns.distplot, "Operating Year")\
   .add_legend();
plt.show();

# %%
sns.FacetGrid(data, hue = "Survival Statistics", size =5)\
   .map(sns.distplot, "Axil nodes")\
   .add_legend();
plt.show();

# %%
plt.scatter(data["Age"], data["Survival Statistics"])
plt.xlabel("Age")
plt.ylabel("Survival")
plt.show()

# %%
plt.scatter(data["Operating Year"], data["Survival Statistics"])
plt.xlabel("Year")
plt.ylabel("Survival")
plt.show()

# %%
plt.scatter(data["Axil nodes"], data["Survival Statistics"])
plt.xlabel("nodes")
plt.ylabel("Survival")
plt.show()

# %%
sns.pairplot(data, hue = "Survival Statistics", height = 3)
plt.show()
# Out:
# C:\Users\kalyani raghavendra\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\kalyani raghavendra\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
sns.pairplot(data, vars = ["Age","Axil nodes"])

# %%
#CDF and PDF
counts, bin_edges = np.histogram(data['Age'], bins = 10, density = True)
plt.xlabel('Age')
pdf = counts/(sum(counts))
print("pdf=", pdf);
print("bin_edges=", bin_edges);
cdf = np.cumsum(pdf)
print("cdf=", cdf)
plt.plot(bin_edges[1:], pdf);
plt.plot(bin_edges[1:], cdf)
# Out:
# pdf= [0.05228758 0.08823529 0.1503268  0.17320261 0.17973856 0.13398693
#  0.13398693 0.05882353 0.02287582 0.00653595]
# bin_edges= [30.  35.3 40.6 45.9 51.2 56.5 61.8 67.1 72.4 77.7 83. ]
# cdf= [0.05228758 0.14052288 0.29084967 0.46405229 0.64379085 0.77777778
#  0.91176471 0.97058824 0.99346405 1.        ]

# %%
sns.boxplot(x ="Survival Statistics", y= "Age", data = data)
plt.show()

# %%
sns.boxplot(x ="Survival Statistics", y= "Operating Year", data = data)
plt.show()

# %%
sns.violinplot(x ="Survival Statistics", y= "Operating Year", data = data, size = 8)
plt.show()

# %%
sns.violinplot(x ="Survival Statistics", y= "Age", data = data, size = 5)
plt.show()

# %%
#Q - Q Plot
import numpy as np
import pylab
import scipy.stats as stats

std_normal = np.random.normal(loc = 0, scale = 1, size = 1000) #loc = mean, scale = std deviation

for i in range(0,101):
    print(i, np.percentile(std_normal, i))
# Out:
# 0 -3.087521678201222
# 1 -2.4689534286879726
# 2 -2.129815699704836
# 3 -1.9093763123169525
# 4 -1.7827072200517822
# 5 -1.6943483805089874
# 6 -1.6503891741465395
# 7 -1.5889373803656799
# 8 -1.523455496967052
# 9 -1.4711145616014607
# 10 -1.3945930766455703
# 11 -1.3195164515277793
# 12 -1.2857674950124904
# 13 -1.2493959488758575
# 14 -1.186344366259258
# 15 -1.1265282062203823
# 16 -1.0786509080652802
# 17 -1.02799591860596
# 18 -0.9876376499087018
# 19 -0.9556605615774121
# 20 -0.9118018251177687
# 21 -0.864116493943407
# 22 -0.833704201222741
# 23 -0.8044224075633097
# 24 -0.7564910681307219
# 25 -0.7320405444927234
# 26 -0.696176627814615
# 27 -0.6720408605110408
# 28 -0.6379559382368679
# 29 -0.6043745337616877
# 30 -0.5729535471602053
# 31 -0.5526432279933093
# 32 -0.5266231111011513
# 33 -0.5041185789247922
# 34 -0.4679298636105057
# 35 -0.44715645358248335
# 36 -0.41069834347066003
# 37 -0.37225516069727205
# 38 -0.3474149860452307
# 39 -0.3244639368556641
# ...

# %%
measurements = np.random.normal(loc = 20, scale=5, size = 100)

stats.probplot(measurements, dist = "norm", plot=pylab) 
pylab.show()

# %%
measure = np.random.normal(loc =20, scale = 5, size = 1000)

stats.probplot(measure, dist ="norm", plot = pylab)
pylab.show()

# %%
measure = np.random.uniform(low =-1, high = 1, size = 10000)

stats.probplot(measure, dist = "norm", plot = pylab)
pylab.show()

# %% [markdown]
# Iam testing my skills.
